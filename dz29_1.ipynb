# %% [markdown]
# ##  Перевірка статистичних гіпотез

# %% [markdown]
# ### Задача 1

# %% [markdown]
# Протягом 50 років вимірювався рівень води навесні під час повені відносно умовного нуля. Результати вимірювання наведено у
# вигляді інтервального статистичного розподілу:

# %% [markdown]
# |  $x_i$   | 0-24   | 24-48  | 48-72  | 72-96  | 96-120 | 120-144 | 144-168 | 168-192 | 192-216 |
# |:---      | :---:  | :---:  | :---:  | :---:  | :---:  | :---:   | :---:   | :---:   | :---:   |
# | $n_i$    | 1      | 2      | 4      | 6      | 12     | 16      | 6       | 2       | 1       |

# %% [markdown]
# За заданими статистичними розоподілами вибірки висунути $ H_0 $ про закон розподілу ознаки генеральної сукупності і при рівні значущості $ \alpha = 0,01 $ перевірити її правильність.

# %% [markdown]
# ### Розв'язок

# %% [markdown]
# #### $ H_0 $ - припустимо, що генеральна сукупністть має нормальний закон розподілу.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Для того, щоб при заданому рівні значущості $\alpha $ перевірити гіпотезу про нормальний розподіл генеральної сукупності, необхідно:**

# %% [markdown]
# #### 1. Обчислити вибіркове середнє $\overline{x_B} $ і середнє квадратичне відхилення вибірки $ \sigma_в $

# %% [markdown]
# Для цього перетворимо інтервальний статистичний розподіл вибірки на точковий:

# %% [markdown]
# |  $x_i$   | 12     | 36     | 60     | 84     | 108    | 132     | 156     | 180     | 204     |
# |:---      | :---:  | :---:  | :---:  | :---:  | :---:  | :---:   | :---:   | :---:   | :---:   |
# | $n_i$    | 1      | 2      | 4      | 6      | 12     | 16      | 6       | 2       | 1       |

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Вибіркове середнє**

# %% [markdown]
# $ \overline{x_B} = \frac{1}{n}  \sum{x_i ∙ n_i} $,
#
# де n = 50

# %%
(12*1 + 36*2 + 60*4 + 84*6 + 108*12 + 132*16 + 156*6 + 180*2 + 204*1)/50
# Out:
# 114.72

# %% [markdown]
# $ \overline{x_в} = 114,72$,

# %% [markdown]
# **Дисперсія та середнє квадратичне відхилення вибірки**

# %% [markdown]
# $ D_B = \frac{\sum{x_i^2 n_i}}{n}  - (\overline{x_в})^2 = 1452,44 $

# %%
((12**2*1 + 36**2*2 + 60**2*4 + 84**2*6 + 108**2*12 + 132**2*16 + 156**2*6 + 180**2*2 + 204**2*1)/50) - (114.72**2)
# Out:
# 1452.441600000002

# %% [markdown]
# $ \sigma_в = \sqrt{D_в} = 38,11 $

# %%
1452.4416**0.5
# Out:
# 38.11091182325608

# %% [markdown]
# $ \overline{x_в} = 114,74 $,

# %% [markdown]
# $ \sigma_в = 38,11 $

# %% [markdown]
# #### 2. Знайти нормовані інтервали, враховуючи, що вибіркове середнє $ \overline{x_B} = 114,74 $, і середнє квадратичне відхилення вибірки $ \sigma_в = 38,11 $ та обчислимо теоретичні частоти.

# %% [markdown]
# Знайдемо нормовані інтервали, враховуючи, що вибіркове середнє $ \overline{x_B} = 114,74 $, і середнє квадратичне відхилення вибірки $ \sigma_в = 38,11 $.
#
# Для цього складемо розрахункову таблицю (лівий кінець першого інтервалу вважаємо рівним $-\infty$ , а правий кінець останнього інтервалу рівним $+\infty$.
#
# Визначимо теоретичні ймовірності $P_i$ і теоретичні частоти $n_i'$:

# %% [markdown]
# $ n_i' = n ∙ P_i $

# %% [markdown]
# Для цього складемо розрахункову таблицю:

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 3. Порівняти емпіричні та теоретичні частоти, використовуючи критерій Пірсона.

# %% [markdown]
# Для цього обчислимо спочатку спостережуване значення критерію Пірсона за допомогою розрахункової таблиці:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# З таблиці видно, що
#
# $\chi_{сп}^2 = \sum_{i=1}^m\frac{n_i - n'_i}{n'_i} = 4,4824 $

# %% [markdown]
# Оскільки $ = \sum_{i=1}^m\frac{n_i^2}{n'_i} - 50 = 54,4824 = 4,4824 = \chi_{сп}^2 $,
#
# то обчислення проведено правильно.

# %% [markdown]
# За таблицею критичних точок розподілу $\chi^2$ при рівні значущості $ \alpha = 0,01 $ і кількості ступенів вільності
#
# $r = m - s -1 = 9 - 2 - 1 = 6 $
#
# знайдемо критичну точку правосторонньої критичної області:
#
# $ \chi_{крит}^2 = (0,01; 6) = 16,8 $

# %% [markdown]
# Оскільки $\chi_{сп}^2 < \chi_{крит}^2 $, гіпотезу про нормальний розподіл генеральної сукупності не відхиляємо. Тобто, емпіричні та теоретичні частоти відрізняються несуттєво.

# %% [markdown]
# $\chi_{сп}^2 = 4,4824 $
#
# $ \chi_{крит}^2 = 16,8 $

# %% [markdown]
# ### Відповідь:

# %% [markdown]
# **Оскільки $\chi_{сп}^2 < \chi_{крит}^2 $, гіпотезу про нормальний розподіл генеральної сукупності не відхиляємо.**
#
# **Тобто, емпіричні та теоретичні частоти відрізняються несуттєво.**
