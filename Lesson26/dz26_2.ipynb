# %% [markdown]
# ##  Статистика

# %% [markdown]
# ### Задача 2

# %% [markdown]
# При вивченні випадкової величини X у результаті 40 незалежних спостережень дістали вибірку:
#
# 10, 13, 10, 9, 9, 12, 12, 6, 7, 9, 8, 9, 11, 9, 14, 13, 9, 8, 8, 7, 10, 10, 11, 11, 11, 12, 8, 7 ,9, 10, 14, 13, 8,
# 8, 9, 10, 11, 11, 12, 12.
#
# Побудувати дискретний статистичний розподіл для цієї вибірки, а також
# полігон частот і F*(х). Знайти моду та медіану.

# %% [markdown]
# ### Розв'язок

# %% [markdown]
# ### 1. Статистичний розподіл вибірки

# %% [markdown]
# Об'єм вибірки **n = 40**

# %% [markdown]
# Статистичний розподіл частот, де $x_i$ - варіанта,  $n_i$ - частота

# %% [markdown]
# |  $x_i$   | 6     | 7     | 8     | 9     | 10    | 11    | 12    | 13    | 14    |
# |:---      | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: |
# | $n_i$    | 1     | 3     | 6     | 8     | 6     | 6     | 5     | 3     | 2     |

# %% [markdown]
# Статистичний розподіл відносних частот, де $x_i$ - варіанта,  $w_i = \frac{n_i}{n}$ - відносна частота

# %% [markdown]
# |  $x_i$   | 6     | 7     | 8     | 9     | 10    | 11    | 12    | 13    | 14    |
# |:---      | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: |
# | $w_i$    | 0,025 | 0,075 | 0,15  | 0,2   | 0,15  | 0,15  | 0,125 | 0,075 | 0,05  |

# %% [markdown]
# ### 2.1  Полігон частот

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2.2  Полігон відносних частот

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. Емпірична (вибіркова) функція розподілу

# %% [markdown]
# $ F^*(x) = \frac{n_x}{n} $, де
#
# $n_i = \sum_{x_s<x}$

# %% [markdown]
# Значення $ n_x $ буде змінюватися у точках таблиці $ x_i $. Для нашого випадку:

# %% [markdown]
# \[ $F^*(x)$ = \begin{cases}
# 0,  &  \text{якщо  $ x_i \leq 6$}\\
# 1/40,  & \text{  якщо $ 6 < x_i \leq 7$}\\
# (1 + 3)/40, & \text{  якщо $ 7 < x_i \leq 8$}\\
# (4 + 6)/40, & \text{  якщо $ 8 < x_i \leq 9$}\\
# (10 + 8)/40, & \text{  якщо $ 9 < x_i \leq 10$}\\
# (18 + 6)/40, & \text{   якщо $ 10 < x_i\leq 11$}\\
# (24 + 6)/40, & \text{  якщо $ 11 < x_i \leq 12$}\\
# (30 + 5)/40, & \text{  якщо $ 12 < x_i \leq 13$}\\
# (35 + 3)/40, & \text{  якщо $ 13 < x_i \leq 14$}\\
# (38 + 2)/40 & \text{якщо $x_i > 14 $.}
# \end{cases}\]

# %% [markdown]
# |  $x_i$   | 6     | 7     | 8     | 9     | 10    | 11    | 12    | 13    | 14    |
# |:---      | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: | :---: |
# | $F()x$   | 0,025 | 0,1   | 0,25  | 0,45  | 0,6   | 0,75  | 0,875 | 0,95  | 1     |

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Ще один вид графіка емпіричної функції розподіду

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4. Мода

# %% [markdown]
# **Модою $ M_0 $ варіаційного ряду називають варінту, яка має найбільшу частоту**

# %% [markdown]
# $ M_0 = 9 $

# %% [markdown]
# ### 5. Медіана

# %% [markdown]
# **Медіаною $ M_e $ варіаційного ряду називають варіанту, яка ділить ряд на дві частини, рівні за кількістю варіант.**
#
# Якщо число варіант непарне, $ k = 2m + 1 $, то медіана
# $ M_e = x_{m+1} $
#
# Якщо число варіант парне, $ k = 2m $, то медіана
#
# $ M_e = \frac{1}{2} ∙ (x_m + x_{m+1}) $

# %% [markdown]
# В задачі число варіант парне і дорівнює 40.

# %% [markdown]
# $ M_e = \frac{1}{2} ∙ (x_{20} + x_{21}) $

# %%
1/2*(7 + 10)
# Out:
# 8.5

# %% [markdown]
# ### Відповідь:

# %% [markdown]
# **Мода варіаційного ряду:**
#
# $ M_0 = 9 $
#
# **Медіана варіаційного ряду:**
#
# $ M_e = 8,5 $
