# %% [markdown]
# ## Елементарні перетворення матриці

# %% [markdown]
# Використовуючи елементарні перетворення рядків, перетворити матрицю A в верхню трикутну матрицю, де:
#
# ![image-5.png](attachment:image-5.png)

# %%
import numpy
A = numpy.array([[4, 2, 0],[1, 3, 2],[-1, 3, 10]])
print(A)
# Out:
# [[ 4  2  0]
#  [ 1  3  2]
#  [-1  3 10]]

# %% [markdown]
# ## Розвязок:

# %% [markdown]
# 1. Поміняємо перший та другий рядок місцями
#
# ![image.png](attachment:image.png)

# %%
A1 = numpy.array([A[1],A[0],A[2]])
print(A1)
# Out:
# [[ 1  3  2]
#  [ 4  2  0]
#  [-1  3 10]]

# %% [markdown]
# 2. До 2-го рядка додати 1-ший, помножений на -4; до третього рядка додати перший
#
# ![image.png](attachment:image.png)

# %%
A2 = numpy.array([A1[0], A1[1]+A1[0]*(-4), A1[2]+A1[0]])
print(A2)
# Out:
# [[  1   3   2]
#  [  0 -10  -8]
#  [  0   6  12]]

# %% [markdown]
# 3. 2-ий рядок поділити на -2, третій рядок ділимо на 6
#
# ![image.png](attachment:image.png)

# %%
A3 = numpy.array([A2[0], A2[1]/(-2), A2[2]/6], dtype=int)
print(A3)
# Out:
# [[1 3 2]
#  [0 5 4]
#  [0 1 2]]

# %% [markdown]
# 4. Поміняємо другий та третій рядок місцями
#
# ![image.png](attachment:image.png)

# %%
A4 = numpy.array([A3[0], A3[2], A3[1]])
print(A4)
# Out:
# [[1 3 2]
#  [0 1 2]
#  [0 5 4]]

# %% [markdown]
# 5. До 3-тього рядка додамо 2-ий, помножений на -5
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ______________

# %%
A5 = numpy.array([A4[0], A4[1], A4[2]+A4[1]*(-5)])
print(A5)
# Out:
# [[ 1  3  2]
#  [ 0  1  2]
#  [ 0  0 -6]]
